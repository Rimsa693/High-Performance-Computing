# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('rimsalr00.csv', delimiter=',')

# %%
df
# Out:
#          x       y
# 0    77.71  118.37
# 1    79.99  117.25
# 2    69.06  122.31
# 3    69.44   97.80
# 4    78.39  133.72
# ..     ...     ...
# 995  33.52   52.58
# 996  44.61   66.12
# 997  31.67   65.82
# 998  50.45   70.54
# 999  45.07   76.15
#
# [1000 rows x 2 columns]

# %%
y = df['y'];
x = df['x'];

# %%
plt.xlabel('x'); plt.ylabel('y');
plt.scatter(x,y)

# %%
plt.plot((0,100), (5,140), 'y')
plt.scatter(df.x, df.y)

# %%
plt.plot((0,100), (29,166), 'r')
plt.scatter(df.x, df.y)

# %%
plt.plot((0,100), (50,186), 'y')
plt.scatter(df.x, df.y)

# %%
plt.scatter(x,y)
plt.plot((0,100), (5,140), 'y')
plt.plot((0,100), (29,166), 'r')
plt.plot((0,100), (50,186), 'y')
plt.scatter(df.x, df.y)

# %%
plt.show()

# %%
df = pd.read_csv('rimsalr01.csv', delimiter=',')

# %%
plt.scatter(df.x, df.y)
